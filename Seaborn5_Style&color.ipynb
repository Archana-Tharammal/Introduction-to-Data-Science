# %% [markdown]
# <a href="https://colab.research.google.com/github/Archana-Tharammal/Introduction-to-Data-Science/blob/main/Seaborn5_Style%26color.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips=sns.load_dataset('tips')

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex',data=tips)
sns.despine()

# %%
sns.countplot(x='sex',data=tips)
sns.despine(left=True)

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill',y='tip',height=2,aspect=4,data=tips)

# %%
sns.set_context('poster',font_scale=4)
sns.countplot(x='sex',data=tips,palette='coolwarm')
# Out:
# <Axes: xlabel='sex', ylabel='count'>
